# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv')

# %%
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
df.isnull().sum()/len(df)
# Out:
# Unnamed: 0                           0.000000
# id                                   0.000000
# Gender                               0.000000
# Customer Type                        0.000000
# Age                                  0.000000
# Type of Travel                       0.000000
# Class                                0.000000
# Flight Distance                      0.000000
# Inflight wifi service                0.000000
# Departure/Arrival time convenient    0.000000
# Ease of Online booking               0.000000
# Gate location                        0.000000
# Food and drink                       0.000000
# Online boarding                      0.000000
# Seat comfort                         0.000000
# Inflight entertainment               0.000000
# On-board service                     0.000000
# Leg room service                     0.000000
# Baggage handling                     0.000000
# Checkin service                      0.000000
# ...

# %%
df.dropna(subset=['Arrival Delay in Minutes'],inplace=True)
df
# Out:
#         Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0                0   70172    Male     Loyal Customer   13  Personal Travel
# 1                1    5047    Male  disloyal Customer   25  Business travel
# 2                2  110028  Female     Loyal Customer   26  Business travel
# 3                3   24026  Female     Loyal Customer   25  Business travel
# 4                4  119299    Male     Loyal Customer   61  Business travel
# ...            ...     ...     ...                ...  ...              ...
# 103899      103899   94171  Female  disloyal Customer   23  Business travel
# 103900      103900   73097    Male     Loyal Customer   49  Business travel
# 103901      103901   68825    Male  disloyal Customer   30  Business travel
# 103902      103902   54173  Female  disloyal Customer   22  Business travel
# 103903      103903   62567    Male     Loyal Customer   27  Business travel
#
# ...

# %%
df['Class'].value_counts(normalize=True)
# Out:
# Business    0.478145
# Eco         0.449765
# Eco Plus    0.072089
# Name: Class, dtype: float64

# %%
plt.style.use('seaborn')
df['Class'].hist()
# Out:
# <AxesSubplot:>

# %%
df.Age.value_counts()/len(df)
# Out:
# 39    0.028583
# 25    0.026932
# 40    0.024799
# 44    0.023930
# 42    0.023679
#         ...
# 74    0.000454
# 76    0.000434
# 79    0.000405
# 78    0.000319
# 85    0.000164
# Name: Age, Length: 75, dtype: float64

# %%
df.Age.plot.hist(bins=10).set_ylabel('Quantity')
# Out:
# Text(0, 0.5, 'Quantity')

# %%
df['satisfaction'].value_counts(normalize=True)
# Out:
# neutral or dissatisfied    0.566606
# satisfied                  0.433394
# Name: satisfaction, dtype: float64

# %%
new_df = df[df['satisfaction'] == 'satisfied']
new_df['Gender'].value_counts(normalize=True)
# Out:
# Female    0.500457
# Male      0.499543
# Name: Gender, dtype: float64

# %%
new_df['Type of Travel'].value_counts(normalize=True)
# Out:
# Business travel    0.927323
# Personal Travel    0.072677
# Name: Type of Travel, dtype: float64

# %%
new_df['Class'].value_counts(normalize=True)
# Out:
# Business    0.765975
# Eco         0.193131
# Eco Plus    0.040894
# Name: Class, dtype: float64

# %%
new_df['Customer Type'].value_counts(normalize=True)
# Out:
# Loyal Customer       0.900127
# disloyal Customer    0.099873
# Name: Customer Type, dtype: float64

# %%
fig, ax = plt.subplots(1, 3, figsize = (15, 5)) 
df[df['Class'] == 'Eco']['Flight Distance'].plot.box(ax = ax[0])
df[df['Class'] == 'Eco Plus']['Flight Distance'].plot.box(ax = ax[1])
df[df['Class'] == 'Business']['Flight Distance'].plot.box(ax = ax[2])
ax[0].set_xlabel('Class = Eco')  
ax[1].set_xlabel('Class = Eco Plus')  
ax[2].set_xlabel('Class = Business')  
ax[0].set_ylabel('Flight Distance')
# Out:
# Text(0, 0.5, 'Flight Distance')

# %%
df1 = df.sort_values(by = 'Flight Distance', ascending = False, ignore_index = True)
df1['Flight Distance'].plot().set_ylabel('Flight Distance')
# Out:
# Text(0, 0.5, 'Flight Distance')

# %%
corr1 = df[['Inflight wifi service','Departure/Arrival time convenient','Ease of Online booking','Gate location','Food and drink','Online boarding',
'Seat comfort','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service','Cleanliness']].corr()
print(corr1)
# Out:
#                                    Inflight wifi service  \
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.343758
# Ease of Online booking                          0.715848
# Gate location                                   0.336127
# Food and drink                                  0.134603
# Online boarding                                 0.457002
# Seat comfort                                    0.122617
# Inflight entertainment                          0.209513
# On-board service                                0.121484
# Leg room service                                0.160485
# Baggage handling                                0.121060
# Checkin service                                 0.043178
# Inflight service                                0.110626
# Cleanliness                                     0.132652
#
#                                    Departure/Arrival time convenient  \
# ...

# %%
import seaborn as sns
heatmap = sns.heatmap(corr1, cmap='GnBu')
plt.show()

# %%
def get_satisfaction_label(x):
    if x['satisfaction'] == 'satisfied':
        return 1
    else:
        return 0

# %%
df.loc[:, 'satisfaction_label'] = df.apply(get_satisfaction_label, axis=1)

# %%
df.head()
# Out:
#    Unnamed: 0      id  Gender      Customer Type  Age   Type of Travel  \
# 0           0   70172    Male     Loyal Customer   13  Personal Travel
# 1           1    5047    Male  disloyal Customer   25  Business travel
# 2           2  110028  Female     Loyal Customer   26  Business travel
# 3           3   24026  Female     Loyal Customer   25  Business travel
# 4           4  119299    Male     Loyal Customer   61  Business travel
#
#       Class  Flight Distance  Inflight wifi service  \
# 0  Eco Plus              460                      3
# 1  Business              235                      3
# 2  Business             1142                      2
# 3  Business              562                      2
# 4  Business              214                      3
#
#    Departure/Arrival time convenient  ...  On-board service  Leg room service  \
# 0                                  4  ...                 4                 3
# ...

# %%
corr2 = df[['Inflight wifi service','Departure/Arrival time convenient','Ease of Online booking','Gate location','Food and drink','Online boarding',
'Seat comfort','Inflight entertainment','On-board service','Leg room service','Baggage handling','Checkin service','Inflight service','Cleanliness',
'satisfaction_label']].corr()
print(corr2)
# Out:
#                                    Inflight wifi service  \
# Inflight wifi service                           1.000000
# Departure/Arrival time convenient               0.343758
# Ease of Online booking                          0.715848
# Gate location                                   0.336127
# Food and drink                                  0.134603
# Online boarding                                 0.457002
# Seat comfort                                    0.122617
# Inflight entertainment                          0.209513
# On-board service                                0.121484
# Leg room service                                0.160485
# Baggage handling                                0.121060
# Checkin service                                 0.043178
# Inflight service                                0.110626
# Cleanliness                                     0.132652
# satisfaction_label                              0.284163
#
# ...

# %%
import seaborn as sns
heatmap = sns.heatmap(corr2)
plt.show()
